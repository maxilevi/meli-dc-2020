# %%
import pandas as pd
import os
import numpy as np
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
import collections
import helpers


items_dict = helpers.load_items()
interactions_train = helpers.load_interactions_df()

# %%
items_dict[1748830]
# Out:
# {'title': 'Relógio Medidor Inteligente Pulso Freqüência Cardíaca M3',
#  'domain_id': 'MLB-SMARTWATCHES',
#  'product_id': nan,
#  'price': 90.0,
#  'category_id': 'MLB135384',
#  'condition': 'new'}

# %%
domain_item_dict = {}
for item in items_dict.keys():
    domain = items_dict[item]['domain_id']
    if domain not in domain_item_dict:
        domain_item_dict[domain] = []
    domain_item_dict[domain].append(item)

# %%
len(domain_item_dict['MLM-INDIVIDUAL_HOUSES_FOR_SALE'])
# Out:
# 723

# %%
' '.join([items_dict[x]['title'] for x in domain_item_dict['MLM-INDIVIDUAL_HOUSES_FOR_SALE']])
# Out:
# 'Casa Sola En Venta Con Gran Patio Solo Pago De Contado. Se Vende Hotel Boutique De 5 Estrellas, Con 37 Suites Con Vistas Al Mar Caribe Casa En Col. Club De Golf Bellavista, Tlalnepantla. Edo. Mex Casa De 3 Niveles A La Venta En Tultitlán, Izcalli Del Valle Casas En Venta En Fovissste, Manzanillo Majestuosa Residencia Con Inmejorable Ubicación Querétaro, Paseos Del Marqués, Casita En Venta! Casa Remodelada, Excelente Ubicación En Toluca Casa En Condominio - Villas Del Campo Casa En Venta En Centrio Casa En Venta En Bosques De La Florida, San Luis Potosi Casa De Campo En Venta En Villa Guerrero, Ixtapan De La Sal, Estado De México Hermosa Casa Sola En Privada Con Portón Eléctrico En Ahuatepec Bosque De Framboyanes Casa Nueva En Venta (vw) Villa Maya Kankabal, Carretera Izamal-tunkas Km. 21 Linda Casa.  Recuperación Bancaria  Cdmx Desierto De Los Leones, Preciosa Casa Con Salón De Juegos Y Hermoso Jardín Plano Apizaco, Fracc. Parque Ingles, Vendo Recidencia Nueva Casas Nuevas Fraccionamiento Mayorazgo 2 Tehuacan Puebla Casa Duplex En Venta Venta De Casas Solas En San Pedro Cholula Nuevas Bonita Casa En Privada, Muy Iluminada. La Piedad. Casa En Acozac Ixtapaluca Lujosa Casa En Villa Magna A Precio De Oportunidad Hermosa Casa En Fraccionamiento En  Manzanillo Colima Casa - Fraccionamiento Polígono 108 Casa En Venta En Nueva Y Exclusiva Zona Residencial $1,880,000.00 Cerca De Zona Industrial San Luis Potosí Casa En Venta En Bosques De La Florida, San Luis Potosi Casa Sola En Venta Fracc Costa Dorada Casa En Venta  En Jardines De San Manuel Puebla Frente Buap Casa Venta Providencia Hermosa Casa A 5 Minutos De Santa Fe. Magnificas Vistas Casa Sola En Venta Los Portones Torres Lindavista Venta De Casa Casas En Venta En Privada 103, Apodaca Gran Oportunidad!!  Remate De Casa En Ixtapaluca Edomex Casa En Venta Pedregal ¡ Atención Inversionistas !  Lomas Altas, Lomas  2 Casas A Precio De Terreno Casa En Fraccionamiento Con Doble Filtro De Vigilancia Desarrollo Residencial Punta Arena Casa En Venta, Modelo Murano, Riviera Residencial Dentro De Real Del Mar En Tijuana B.c. Casas En Venta En Los Encinos, Apodaca Casa De Recuperación Hipotecaria, Col. Colinas Del Sur Casa Sola En Venta Fracc San Buenaventura Vendo Casa De 2 Y 3 Rec Nueva En Cuautitlan Xaltipa  Excelente Casa En Real De Tultepec Casas En Venta En San José Tetel En Yauhquemehcan Traspaso Casa En Piedra De Agua Una Habitación Puerto Cancun Hermosa Residencia Casa En Venta En Bosques De La Florida Casa Cerca Cuernavaca Morelos Impecable En Ahuantepec Casas En Venta En Xoclan Casa Dividida En 2 Departamentos Casas En Venta En Jardines De Huinalá, Apodaca Se Vende Casa En Tultitlán Centro, Casa, Veta, Cuauhtémoc, Cdmx. Casa - La Pradera Venta De Casa En Haciendas Del Rull Tampico, Tam. Casa Sola En Venta Fatima Venta De Casa En Vista Hermosa Cerca De Galerías Metepec. Remate Bancario El Vergel Qro Casa 3 Recamaras  Remate En Tonalá  Plazuelas De Sn Fco Chis Id-8981 Casa En Venta En Caucel Folio Mcv-105 Venta Casa Real Solare Hermosa Casa En Venta Colinas De San Javier Casa En Venta, Manzanillo, Colima (crm-92-2789)  Santa Maria Insurgentes,casa,venta,cuauhtemoc,cdmx                                                                                                                        Casa  3 Recámaras Lomas Verdes Aprovecha Casita 58m Gran Oportunidad !!!!   Casa En Remate Casa En Venta En Bosques De La Florida Vendo Casa En Hacienda Cuautitlán Casa En Venta En Av. Jardin, Tlatilco, Azcapotzalco Exclusiva Residencia En Venta, En Real De Las Lomas Terreno Frente A La Playa En Venta- Puerto Morelos Excelente Inversión Casa En Alcaldía Cuauhtémoc Remate Hipotecario Casa En Venta El El Fracc Colinas Del Mirador El Marques Qro Casa En Venta En Villas De San José, Tultitlán, Estado De México Casa Venta O Renta En Bosques De Las Lomas Se Renta Departamento En Colonia Nápoles (pb, 100 Metros Casa 3 Niveles 3 Recamaras Valle Dorado Casa Sola En Venta Atempa Con Bonitos Acabados Y Espacios  ...

# %%
interactions_train[interactions_train['event_type'] == 'search']
# Out:
#           user_id                      item_id event_type  \
# 2               0           RELOGIO SMARTWATCH     search
# 20              1        DESMAMADEIRA ELETRICA     search
# 22              1        DESMAMADEIRA ELETRICA     search
# 23              1        DESMAMADEIRA ELETRICA     search
# 25              1        DESMAMADEIRA ELETRICA     search
# ...           ...                          ...        ...
# 11999155   413160  ALUGUEL BOB CAT ESCAVADEIRA     search
# 11999156   413161                        XAOMI     search
# 11999157   413161                        XAOMI     search
# 11999158   413161                        XAOMI     search
# 11999159   413162                COTONETE FINO     search
#
#                        event_timestamp   target
# 2         2019-10-19T11:26:07.063-0400  1748830
# 20        2019-10-07T09:45:29.322-0400   228737
# 22        2019-10-07T09:46:17.100-0400   228737
# 23        2019-10-07T09:46:19.173-0400   228737
# 25        2019-10-07T18:53:20.113-0400   228737
# ...                                ...      ...
# 11999155  2019-10-15T07:14:39.241-0400  2022477
# 11999156  2019-10-03T21:15:49.220-0400  1111021
# 11999157  2019-10-03T21:15:52.335-0400  1111021
# 11999158  2019-10-03T21:16:33.369-0400  1111021
# 11999159  2019-10-01T20:13:11.202-0400  1212472
#
# [6069149 rows x 5 columns]

# %%
len([x for x in items_dict.keys() if items_dict[x].condition == 'new'])

# %%
keys = list(items_dict.keys())

def normalize(item_title):
    return item_title.upper().strip().replace('.', '')

document_to_item = collections.defaultdict(list)
for x in keys:
    document_to_item[normalize(items_dict[x]['title'])].append(x)
    
documents = list(document_to_item.keys())

vectorizer = TfidfVectorizer(stop_words=['spanish', 'portuguese'], strip_accents='unicode', min_df=5)
X = vectorizer.fit_transform(documents)

# %%
search_queries = list(interactions_train[interactions_train['event_type'] == 'search']['item_id'].dropna().apply(normalize).unique())
len(search_queries)
# Out:
# 847430

# %%
q = vectorizer.transform(search_queries)
q
# Out:
# <847430x377332 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2752723 stored elements in Compressed Sparse Row format>

# %%
# %%time
n = 10
heap = []
indexed_results = {}

for j in range(200):#q.shape[0])
    heap = []
    y = q.getrow(j)
    r = X.multiply(y).sum(1)
    rows, cols = r.nonzero()
    for i in range(len(rows)):
        val = r[rows[i], cols[i]]
        heapq.heappush(heap, (val, document_to_item[documents[rows[i]]]))
        if len(heap) > n:
            heapq.heappop(heap)
    indexed_results[search_queries[j]] = sorted(heap, key=lambda x: -x[0])
    if j % 1000 == 0 and j > 0:
        print('Saving pickle...')
        with open('./search.pickle', 'wb') as handle:
            pickle.dump(indexed_results, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Saved pickle!')
# Out:
# CPU times: user 55.8 s, sys: 4.43 s, total: 1min
# Wall time: 1min

# %%
# %%time
n = 10
indexed_results = {}
step = 1000

def f(j):
    y = q.getrow(j)
    r = X.multiply(y).sum(1)
    #rows, cols = r.nonzero()
    #for i in range(len(rows)):
    #    val = r[rows[i], cols[i]]
    #    heapq.heappush(heap, (val, document_to_item[documents[rows[i]]]))
    #    if len(heap) > n:
    #        heapq.heappop(heap)
    indexed_results[search_queries[j]] = document_to_item[documents[np.argmax(r)]][0]#sorted(heap, key=lambda x: -x[0])
    #print(f"Finished {j}")
    if j % 1000 == 0 and j > 0:
        print('Saving pickle...')
        with open('./search.pickle', 'wb') as handle:
            pickle.dump(indexed_results, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print('Saved pickle!')

#f(0)
for i in range(100):
    f(i)
# Out:
# CPU times: user 17 s, sys: 2.24 s, total: 19.2 s
# Wall time: 19.2 s

# %%
indexed_results
# Out:
# {'RELOGIO SMARTWATCH': [95155, 313617, 1512214, 814788, 1469577],
#  'DESMAMADEIRA ELETRICA': [1156086],
#  'RADIOBOSS': [1230082],
#  'SOUND FORGE': [337971],
#  'SOUND FORGE PLUGINS': [937557],
#  'AMAZFIT BIP': [1968144, 1258600, 1364544, 1821786],
#  'AMAZFIT BIPAMAZFIT BIP LITE': [66654],
#  'AMAZFIT BIPAMAZFIT BIP': [1968144, 1258600, 1364544, 1821786],
#  'PULA PULA': [2058570, 2014165],
#  'CABANA': [634923],
#  'CARREGADOR 34A': [939286],
#  'KINGS 34': [909618],
#  'KINGS 34A': [939286],
#  'GALAXY BUDS': [1087758, 1520178],
#  'FONE XIAOMI': [1886003],
#  'TAMPA TRASEIRA IPHONE8': [68885],
#  'CAMBIO C4 PALLAS': [1782636],
#  'LEECO COOL 1 DISPLAY': [1855680],
#  'LEECO COOL 1 DISPLAY C103': [1855680],
#  'SECADOR TAIFF': [40480],
#  'AUDIFONOS BASS': [426544],
#  'ILUMINADOR LED RING LIGHT MAQUIAGEM MAKE FOTOS': [426711],
#  'HARMAN KARDON': [1745702],
#  'MEMORIA DDR4': [852207],
#  'MEMORIA DDR4 NOTEBOOK': [1796465],
#  'CARABINAS CHUMBINHO 55': [1091164],
#  'CARABINAS CHUMBINHO 45': [830159],
#  'ESPINGARDA CHUMBINHO 55': [2071669, 404393],
#  'ESPINGARDA CHUMBINHO 5 Q ROSSI': [142460, 449353, 1694620],
#  'ESPINGARDA CHUMBINHO 55 NITRO': [2071669, 404393],
#  'ESPINGARDA CHUMBINHO': [142460, 449353, 1694620],
#  '928 TYPE': [390626],
#  'ORGANIZADOR SAPATOS': [260073],
#  'CABIDES': [603760],
#  'LIVRO 100': [802908],
#  'LEMBRANCAS': [334659],
#  'LEMBRANCAS FAMILIA': [334659],
#  'FILHOTE CACHORRO BASSET DASCHUND': [567046],
#  'BANCADA MAQUIAGEM MDF': [975814],
#  'ORGANIZADOR MAQUIAGEM ACRILICO': [619551, 1770507],
#  'ORGANIZADOR MAQUIAGEM ACRILICO GIRATORIO': [16390],
#  'CADEIRA PODOLOGIA': [1148638],
#  'LICENCA WINDOWS': [434986],
#  'LICENCA WINDOWS 10': [434986],
#  'JBL GO 2': [1629275],
#  'REMEDIOS EMAGRECIMENTO SLIM': [93403],
#  'PLATAFORMA TESOURA 6 METROS': [347438],
#  'ESPINGARDA': [1282825],
#  'ESPINGARDA PRESSAO ROSSI': [1264799],
#  'ESPINGARDA PRESSAO ROSSI LUNETA': [1375984],
#  'VALVULA TRANSFERIDORA PRESSAO': [986475],
#  'VESTIDO FESTA SEREIA PLUS SIZE': [1082661],
#  'PNEU GOODRIDE': [1992996, 700152],
#  'PNEU GOODRIDE 195 65 15': [1670892],
#  'CAMERA IC3 INTELBRAS': [2044003],
#  'CAMERA IC3 INTELBRAS CARTAO': [2044003],
#  'CAMERA IP INTELBRAS IC3': [172549],
#  'LAMPADA ALTA POTENCIA': [1270232],
#  'LAMPADA ALTA POTENCIA 50W': [1849031],
#  'CAPA CORTE BARBEIRO': [828191],
#  'LIMPEZA PELE': [1819456],
#  'MASCARA LIMPEZA PELE': [127621],
#  'MASCARA BLACK HEAD': [2090784],
#  'AR CONDICIONADO 18000 BTUS': [1739896],
#  'TINTA ALEGRIA': [1242118],
#  'MODER DIET': [429310],
#  'DESINCHA': [1686377, 1881019],
#  'BANDEIRAS ACEITAS': [1584582],
#  'MODER DIET JOSI': [1754322],
#  'NARGUILES': [825283],
#  'NARGUILES TRITON': [825283],
#  'SITE NOTA': [989836],
#  'AIRSOFT': [1284102, 1390227],
#  'AIRES PTS': [1576582],
#  'RELOGIO FEMININO': [528909, 526754, 1707976],
#  'RELOGIO FEMININO DIGITAL': [528909, 526754, 1707976],
#  'RELOGIO MASCULINO DIGITAL': [168523, 417091, 1589139, 715935, 902097],
#  'RELOGIO CASIO': [1413236, 1303376],
#  'RELOGIO CASIO AW 80': [25798],
#  'SAPATILHA HAVAIANA': [1625121],
#  'RELOGIO INTELIGENTE SMARTWATCH': [1027377],
#  'COLETE POSTURA FEMININO': [1421536],
#  'GOLF GTI 2019': [1828621, 471305, 629735],
#  'RODAS FUSCA': [1856642,
#   617338,
#   400377,
#   1026768,
#   166346,
#   451320,
#   880583,
#   1597077,
#   1263569],
#  'AR CONDICIONADO 12000 BTUS': [323385, 1269264],
#  'PNEU 175 65 14': [306761],
#  'AMORTECEDOR FIT 2004': [2026053],
#  'FRISO BORRACHA PARACHOQUE CIVIC': [736886],
#  'SHORTS ACADEMIA FEMININO': [98260],
#  'APPLE PENCIL': [1666890],
#  'LANTERNA XHP50': [1501313],
#  'LANTERNA TATICA': [1594043],
#  'LANTERNA T9': [1406793],
#  'S8 HDMI': [1336467],
#  'HDMI L': [1144273],
#  'PANELA MEIA PRESSAO': [1327223],
#  'PUDINZEIRA': [115189],
#  'MEMORIA RAM NOTEBOOK 15V': [474384],
#  'HEADSET GAMER': [1409214, 893611],
#  'CABLE TIPO C': [1954476]}

# %%
results[i] = np.argsort(r.flatten())[-3:][::-1]
print('Saving pickle...')
with open('./search.pickle', 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
print('Saved pickle!')

# %%
from numba import jit, cuda 
import numpy as np 
# to measure exec time 
from timeit import default_timer as timer    
  
# normal function to run on cpu 
def func(a):                                 
    for i in range(10000000): 
        a[i]+= 1      
  
# function optimized to run on gpu  
@jit(target ="cuda")                          
def func2(a):
    for i in range(10000000): 
        a[i]+= 1
if __name__=="__main__": 
    n = 10000000                            
    a = np.ones(n, dtype = np.float64) 
    b = np.ones(n, dtype = np.float32) 
      
    start = timer() 
    func(a) 
    print("without GPU:", timer()-start)     
      
    start = timer() 
    func2(a) 
    print("with GPU:", timer()-start)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b6a5ae551b33> in <module>
# ----> 1 from numba import jit, cuda
#       2 import numpy as np
#       3 # to measure exec time
#       4 from timeit import default_timer as timer
#       5
#
# ModuleNotFoundError: No module named 'numba'

# %%
# %%time

data = {
    'user_id': [],
    'item_id': [],
    'event_type': [],
    'event_timestamp': [],
    'target': []
}

for row in interactions_train[interactions_train['event_type'] == 'search'].iterrows():
    if row['item_id'] not in search_map:
        continue
        
    for r in search_map[row['item_id']]:
        data['user_id'].append(row['user_id'])
        data['item_id'].append(r) 
        data['event_type'].append(row['event_type'])
        data['event_timestamp'].append(row['event_timestamp'])
        data['target'].append(row['target'])

# %%
results
